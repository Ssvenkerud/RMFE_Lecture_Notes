# %% [markdown]
# # 2 Protocol development
# By Simen Svenkerud
#
# ## Outline
#
# * Research question development in the research process
# * What is a study protocol and what infromation does it contain?
# * REsearch protocols and the research process in the real world

# %% [markdown]
# ## Research as a process
#
# 1. Research question
# 2. Systematic review
# 3. Research design
# 4. Data collection
# 5. Data analysis
# 6. Interpretating & conclusions
# 7. Reporting, dissemination & use of research
# 8. Identification of new needs
#
# 1. Rinse and repeat ...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
